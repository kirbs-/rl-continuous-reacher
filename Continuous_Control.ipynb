# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name='Reacher.app', worker_id=1, seed=1)
# Out:
# Mono path[0] = '/Users/ckirby/Nextcloud/git/rl-continuous-reacher/Reacher.app/Contents/Resources/Data/Managed'
# Mono config path = '/Users/ckirby/Nextcloud/git/rl-continuous-reacher/Reacher.app/Contents/MonoBleedingEdge/etc'
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_size -> 5.0
# 		goal_speed -> 1.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 1
# Size of each action: 4
# There are 1 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -7.98051262e+00 -1.00000000e+00
#   5.58052540e-01  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -5.48525572e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
# env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
# states = env_info.vector_observations                  # get the current state (for each agent)
# scores = np.zeros(num_agents)                          # initialize the score (for each agent)
# while True:
#     actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
#     actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
#     print(actions)
#     break
#     env_info = env.step(actions)[brain_name]           # send all actions to tne environment
#     next_states = env_info.vector_observations         # get next state (for each agent)
#     rewards = env_info.rewards                         # get reward (for each agent)
#     dones = env_info.local_done                        # see if episode finished
#     scores += env_info.rewards                         # update the score (for each agent)
#     states = next_states                               # roll over states to next time step
#     if np.any(dones):                                  # exit loop if episode finished
#         break
# print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %%
# env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
def ddpg(n_episodes=500, max_t=1000, print_every=100):
    scores_deque = deque(maxlen=print_every)
    scores = []
    scores_avg = []
    solved = None
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]  # reset the environment
        state = env_info.vector_observations
        agent.reset()
        score = 0
        for t in range(max_t):
            # print(state)
            action = agent.act(state)
            env_info = env.step(action)[brain_name]              # send the action to the environment
            next_state = env_info.vector_observations[0]         # get the next state
            reward = 0.1 if env_info.rewards[0] > 0.0 else 0.0   # get the reward
            # print(env_info.rewards)
            done = env_info.local_done[0]
            agent.step(state, action, reward, next_state, done)
            state = next_state
            score += reward
            if done:
                break 
        scores_deque.append(score)
        scores.append(score)
        avg_score = np.mean(scores_deque)
        scores_avg.append(avg_score)
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, avg_score), end="")
        
        if i_episode % print_every == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, avg_score))
            torch.save(agent.policy_actor.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.value_critic.state_dict(), 'checkpoint_critic.pth')
            
        if avg_score > 30 and i_episode % 100 == 0:
            torch.save(agent.policy_actor.state_dict(), 'model_actor-{}.pth'.format(i_episode))
            torch.save(agent.value_critic.state_dict(), 'model_critic-{}.pth'.format(i_episode))
            
        if not solved and avg_score >= 30: 
            print('\rEpisode {}\tAverage Score: {:.2f}\tSOLVED'.format(i_episode, avg_score))
            solved = True
            
    return scores, scores_avg

# %%
from agent import Agent, Params
import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/ckirby/.pyenv/versions/dlr/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
BATCH_SIZE = 128
GAMMA = 0.99
TAU = 1e-3
LR_ACTOR = 1e-4
LR_CRITIC = 5e-4
STATE_DIM = 33
ACTION_CNT = 4
TARGET_UPDATE_STEP = 20
SEED = 0

params = Params(BATCH_SIZE, GAMMA, TAU, LR_ACTOR, LR_CRITIC, STATE_DIM, ACTION_CNT, TARGET_UPDATE_STEP, SEED)
agent = Agent(params)
# scores, scores_avg = ddpg(2000)

# %%
scores, scores_avg = ddpg(2000)
# Out:
# /Users/ckirby/.pyenv/versions/dlr/lib/python3.9/site-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /Users/ckirby/Nextcloud/git/rl-continuous-reacher/agent.py:162: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(self.value_critic.parameters(), 1)
# Episode 100	Average Score: 2.02
# Episode 200	Average Score: 1.95
# Episode 300	Average Score: 2.08
# Episode 400	Average Score: 2.05
# Episode 500	Average Score: 2.72
# Episode 600	Average Score: 3.39
# Episode 700	Average Score: 5.52
# Episode 800	Average Score: 8.68
# Episode 900	Average Score: 11.03
# Episode 1000	Average Score: 11.85
# Episode 1100	Average Score: 14.23
# Episode 1200	Average Score: 20.18
# Episode 1300	Average Score: 25.45
# Episode 1400	Average Score: 29.52
# Episode 1412	Average Score: 30.08	SOLVED
# Episode 1413	Average Score: 30.31	SOLVED
# Episode 1414	Average Score: 30.40	SOLVED
# Episode 1415	Average Score: 30.41	SOLVED
# Episode 1416	Average Score: 30.38	SOLVED
# Episode 1417	Average Score: 30.36	SOLVED
# Episode 1418	Average Score: 30.31	SOLVED
# Episode 1419	Average Score: 30.38	SOLVED
# Episode 1420	Average Score: 30.36	SOLVED
# Episode 1421	Average Score: 30.51	SOLVED
# Episode 1422	Average Score: 30.61	SOLVED
# Episode 1423	Average Score: 30.70	SOLVED
# Episode 1424	Average Score: 30.80	SOLVED
# Episode 1425	Average Score: 30.89	SOLVED
# Episode 1426	Average Score: 30.98	SOLVED
# Episode 1427	Average Score: 31.11	SOLVED
# Episode 1428	Average Score: 31.27	SOLVED
# Episode 1429	Average Score: 31.39	SOLVED
# Episode 1430	Average Score: 31.52	SOLVED
# Episode 1431	Average Score: 31.67	SOLVED
# Episode 1432	Average Score: 31.69	SOLVED
# Episode 1433	Average Score: 31.62	SOLVED
# Episode 1434	Average Score: 31.60	SOLVED
# Episode 1435	Average Score: 31.80	SOLVED
# Episode 1436	Average Score: 31.81	SOLVED
# Episode 1437	Average Score: 31.81	SOLVED
# Episode 1967	Average Score: 64.25	SOLVED
# Episode 1968	Average Score: 63.96	SOLVED
# Episode 1969	Average Score: 63.75	SOLVED
# Episode 1970	Average Score: 63.90	SOLVED
# Episode 1971	Average Score: 63.99	SOLVED
# Episode 1972	Average Score: 64.15	SOLVED
# Episode 1973	Average Score: 64.11	SOLVED
# Episode 1974	Average Score: 64.11	SOLVED
# Episode 1975	Average Score: 64.18	SOLVED
# Episode 1976	Average Score: 64.49	SOLVED
# Episode 1977	Average Score: 64.56	SOLVED
# Episode 1978	Average Score: 64.75	SOLVED
# Episode 1979	Average Score: 64.76	SOLVED
# Episode 1980	Average Score: 64.73	SOLVED
# Episode 1981	Average Score: 65.04	SOLVED
# Episode 1982	Average Score: 65.10	SOLVED
# Episode 1983	Average Score: 65.12	SOLVED
# Episode 1984	Average Score: 64.99	SOLVED
# Episode 1985	Average Score: 65.07	SOLVED
# Episode 1986	Average Score: 65.16	SOLVED
# Episode 1987	Average Score: 65.34	SOLVED
# Episode 1988	Average Score: 65.36	SOLVED
# Episode 1989	Average Score: 65.57	SOLVED
# Episode 1990	Average Score: 65.54	SOLVED
# Episode 1991	Average Score: 65.56	SOLVED
# Episode 1992	Average Score: 65.71	SOLVED
# Episode 1993	Average Score: 66.05	SOLVED
# Episode 1994	Average Score: 66.01	SOLVED
# Episode 1995	Average Score: 66.12	SOLVED
# Episode 1996	Average Score: 65.85	SOLVED
# Episode 1997	Average Score: 65.85	SOLVED
# Episode 1998	Average Score: 65.88	SOLVED
# Episode 1999	Average Score: 65.88	SOLVED
# Episode 2000	Average Score: 65.96
# Episode 2000	Average Score: 65.96	SOLVED

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.savefig('plot.png')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.savefig('plot.png')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores_avg)+1), scores_avg)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3p/6t38_0bd0l560slr4fmpbb900000gq/T/ipykernel_85954/848964998.py in <module>
#       1 fig = plt.figure()
#       2 ax = fig.add_subplot(111)
# ----> 3 plt.plot(np.arange(1, len(scores_avg)+1), scores_avg)
#       4 plt.ylabel('Score')
#       5 plt.xlabel('Episode #')
#
# NameError: name 'scores_avg' is not defined

# %%
import torch.nn as nn

# %%
for layer in agent.value_critic._modules['linear_relu_stack']:
    if type(layer) == nn.Linear:
        print(layer)
# Out:
# Linear(in_features=33, out_features=256, bias=True)
# Linear(in_features=260, out_features=256, bias=True)
# Linear(in_features=256, out_features=256, bias=True)
# Linear(in_features=256, out_features=4, bias=True)

# %%
mod = agent.value_critic._modules['linear_relu_stack']

# %%
for idx, layer in mod.named_modules():
    print(idx)
    print(layer)
# Out:
# Sequential(
#   (0): Linear(in_features=33, out_features=256, bias=True)
#   (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Linear(in_features=260, out_features=256, bias=True)
#   (4): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): ReLU()
#   (6): Linear(in_features=256, out_features=256, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=256, out_features=4, bias=True)
# )
# 0
# Linear(in_features=33, out_features=256, bias=True)
# 1
# BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 2
# ReLU()
# 3
# Linear(in_features=260, out_features=256, bias=True)
# 4
# BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 5
# ReLU()
# 6
# Linear(in_features=256, out_features=256, bias=True)
# 7
# ReLU()
# 8
# Linear(in_features=256, out_features=4, bias=True)
